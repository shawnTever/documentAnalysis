# %%
import torch.optim
import torch.nn.functional as F
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from models import RNN, GRU, LSTM, AttentionGRU
from synthetic_data import RandomSequenceDataset
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-b6c08ac758a3> in <module>
# ----> 1 import torch.optim
#       2 import torch.nn.functional as F
#       3 import numpy as np
#       4
#       5 import matplotlib.pyplot as plt
#
# D:\Anaconda\Anaconda3\lib\site-packages\torch\__init__.py in <module>
#     114                 err = ctypes.WinError(last_error)
#     115                 err.strerror += ' Error loading "{}" or one of its dependencies.'.format(dll)
# --> 116                 raise err
#     117             elif res is not None:
#     118                 is_loaded = True
#
# OSError: [WinError 127] 找不到指定的程序。 Error loading "D:\Anaconda\Anaconda3\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.

# %%
input_dimension = 4
hidden_dimension = 4
sequence_lengths = [1, 3, 5, 10, 20, 40, 100, 200, 400]
dev = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def train_model(model, optimizer, sequence_length, dimension=input_dimension, batch_size=512):
    dataset = RandomSequenceDataset(dimension, sequence_length, batch_size)
    max_loss = 10
    num_epochs = 100
    epoch_size = 5
    best_loss = 1e10
    for epoch in range(num_epochs):
        average_loss = 0
        for i in range(epoch_size):
            x = dataset.get_batch().to(dev)
            y = x[0]
            y_h = model(x)
            loss = F.mse_loss(y_h, y)
            if np.isnan(loss.item()):
                average_loss += max_loss / epoch_size
                continue
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            average_loss += loss.clamp(0, max_loss).item() / epoch_size
        if average_loss < best_loss:
            best_loss = average_loss
    return best_loss

def plot_losses(losses, sequence_lengths):
    plt.plot(losses)
    plt.xlabel('Sequence Length')
    plt.xticks(range(len(sequence_lengths)), labels=sequence_lengths)
    plt.ylabel('MSE')
    plt.show()

opt = lambda model: torch.optim.Adam(model.parameters(), lr=0.1)


def memory_test(model_func, sequence_lengths):
    losses = []
    for sequence_length in sequence_lengths:
        model = model_func().to(dev)
        optimizer = opt(model)
        loss = train_model(model, optimizer, sequence_length=sequence_length)
        print(f'Sequence length: {sequence_length}, \t running average loss: {loss}')
        losses.append(loss)
    plot_losses(losses, sequence_lengths)

# %%
memory_test(lambda: RNN(input_dimension, hidden_dimension, input_dimension), sequence_lengths)
# Out:
# Sequence length: 1, 	 running average loss: 0.00012311316531850026
# Sequence length: 3, 	 running average loss: 0.9541569948196411
# Sequence length: 5, 	 running average loss: 0.9759913682937622
# Sequence length: 10, 	 running average loss: 0.9692770600318908
# Sequence length: 20, 	 running average loss: 0.9709304809570312
# Sequence length: 40, 	 running average loss: 0.9697231650352477
# Sequence length: 100, 	 running average loss: 0.960527527332306
# Sequence length: 200, 	 running average loss: 0.966009259223938
# Sequence length: 400, 	 running average loss: 0.9563635826110841

# %%
memory_test(lambda: GRU(input_dimension, hidden_dimension, input_dimension), sequence_lengths)
# Out:
# Sequence length: 1, 	 running average loss: 0.001534859393723309
# Sequence length: 3, 	 running average loss: 0.0010884255869314074
# Sequence length: 5, 	 running average loss: 0.001935720443725586
# Sequence length: 10, 	 running average loss: 0.23838135600090027
# Sequence length: 20, 	 running average loss: 0.3235736906528473
# Sequence length: 40, 	 running average loss: 0.485911774635315
# Sequence length: 100, 	 running average loss: 0.48460489511489874
# Sequence length: 200, 	 running average loss: 0.9557649493217468
# Sequence length: 400, 	 running average loss: 0.9641095638275146

# %%
memory_test(lambda: LSTM(input_dimension, hidden_dimension, input_dimension), sequence_lengths)
# Out:
# Sequence length: 1, 	 running average loss: 0.003058713674545288
# Sequence length: 3, 	 running average loss: 0.00281684473156929
# Sequence length: 5, 	 running average loss: 0.0019247817806899547
# Sequence length: 10, 	 running average loss: 0.9677029728889466
# Sequence length: 20, 	 running average loss: 0.9718386054039002
# Sequence length: 40, 	 running average loss: 0.9742437243461608
# Sequence length: 100, 	 running average loss: 0.9644433498382569
# Sequence length: 200, 	 running average loss: 0.9740870833396912
# Sequence length: 400, 	 running average loss: 0.9668138742446899

# %%
memory_test(lambda: AttentionGRU(input_dimension, hidden_dimension, input_dimension), sequence_lengths)
# Out:
# Sequence length: 1, 	 running average loss: 9.277784170062135e-16
# Sequence length: 3, 	 running average loss: 1.7252964863178112e-15
# Sequence length: 5, 	 running average loss: 2.074057904588589e-11
# Sequence length: 10, 	 running average loss: 1.8978488502556557e-15
# Sequence length: 20, 	 running average loss: 1.4152878088230517e-13
# Sequence length: 40, 	 running average loss: 3.135865980948005e-12
# Sequence length: 100, 	 running average loss: 2.942815601121064e-14
# Sequence length: 200, 	 running average loss: 2.9342081454846903e-15
# Sequence length: 400, 	 running average loss: 2.490220261950943e-15
